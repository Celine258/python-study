# %%
import json
data=[{"name":"Celine","age":18}]
json_str=json.dumps(data,ensure_ascii=False)#python对象转化为json字符串
print(json_str)
data=json.loads(json_str)#json字符串转化为python对象
print(data)
print(type(data))
print(type(json_str))
# Out:
# [{"name": "Celine", "age": 18}]
# [{'name': 'Celine', 'age': 18}]
# <class 'list'>
# <class 'str'>
