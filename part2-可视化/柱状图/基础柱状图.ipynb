# %%
from pyecharts.charts import Bar
from pyecharts import options as opts 
bar = Bar()
bar.add_xaxis(["美国","中国","英国"])
bar.add_yaxis("GDP",[30,20,10],label_opts=opts.LabelOpts(position="right",font_weight="bold",font_size="24"))
bar.reversal_axis()
bar.render("Bar.html")
# Out:
# 'd:\\Python学习\\part2\\柱状图\\Bar.html'
