# %%
from pyecharts.charts import Line
line = Line()
line.add_xaxis(["China","American","Japen"])
line.add_yaxis("GDP",[30,20,10])
line.render()
# Out:
# 'd:\\Python学习\\part2\\可视化图表开发new\\render.html'
