# %%
class Student:
    name: None
    gender = None
    nationality = None
    native_place = None
    age = None
    def say_hi(self):#self必须带上，要是用变量必须通过self
        print(f"Hello.I`m {self.name}")
    def say_hi2(self, msg):
        print(f"Hi,I`m {self.name}.{msg}")

    def __str__(self):
        return f"student类对象,name:{self.name},age:{self.age}"

    def __lt__(self, other):
        return self.age < other.age

    def __le__(self, other):
        return self.age <= other.age

    def __eq__(self, value):
        return self.age == value.age

stu1 = Student()
stu2 = Student()
stu1.name = "Alex"
stu1.gender = "man"
stu1.nationality = "USA"
stu1.age = 12
stu1.native_place = "China"
stu1.say_hi()
stu1.say_hi2("Nice to meet")
stu2.name = "Steve"
stu2.age = 13
print(str(stu1))
print(stu1 > stu2)
print(stu1 <= stu2)
print(stu1 == stu2)
# Out:
# Hello.I`m Alex
# Hi,I`m Alex.Nice to meet
# student类对象,name:Alex,age:12
# False
# True
# False
