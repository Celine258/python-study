# %%
cars=['bwm','audi','subaru','toyota']
for car in cars:
    if car == 'bwm':
        print(car.upper())
    else:
        print(car.title())
# Out:
# BWM
# Audi
# Subaru
# Toyota

# %%
age=18
age < 20
# Out:
# True

# %%
age_1=10
age_2=20
age_1<20 or age_2>20
# Out:
# True

# %%
age_1<20 and age_2>20
# Out:
# False

# %%
people=['admin','alex','eric','dio','subaru']
for i in people:
    if i == 'admin':
        print("Hello admin,would you like to see status report.")
    else:
        print(f"Hello {i},thank you for logging again.")
# Out:
# Hello admin,would you like to see status report.
# Hello alex,thank you for logging again.
# Hello eric,thank you for logging again.
# Hello dio,thank you for logging again.
# Hello subaru,thank you for logging again.

# %%
users=[]
if users:
    for i in users:
        if i == 'admin':
            print("Hello admin,would you like to see status report.")
        else:
            print(f"Hello {i},thank you for logging again.")
else:
    print("We need find some users.")
# Out:
# We need find some users.

# %%
current_users=people[:]
new_users=['alex','Rupa','Nina','Momoka','subaru']
for i in new_users:
    if i in current_users:
        print("Your name had been used,plz try other name.")
    else:
        print("Nobody uses this name.")
# Out:
# Your name had been used,plz try other name.
# Nobody uses this name.
# Nobody uses this name.
# Nobody uses this name.
# Your name had been used,plz try other name.

# %%
for i in range(1,10):
    if i == 1:
        print("1st\n")
    elif i == 2:
        print("2nd\n")
    elif i == 3:
        print("3rd\n")
    else:
        print(f"{i}th\n")
# Out:
# 1st
#
# 2nd
#
# 3rd
#
# 4th
#
# 5th
#
# 6th
#
# 7th
#
# 8th
#
# 9th
